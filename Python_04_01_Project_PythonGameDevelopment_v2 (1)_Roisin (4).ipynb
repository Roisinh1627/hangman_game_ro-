# %% [markdown]
# <h1 style="text-align:center; font-size: 5em;">Project: Python Game Development</h1>
# <hr style="border:2px solid">
# <h1 style="text-align:center; font-size: 3em;">Project Overview</h1>
# <hr style="border-top:1px dashed">
#
#
# ## Welcome to the First Python Project!
#
# Create a simple and interactive game using Python, incorporating fundamental programming concepts and Python basics. This project aims to reinforce your understanding of core Python principles while fostering creativity through game development.
#
# ### Game options:
#
# #### Guess the Number:
#
# The computer randomly selects a number, and the player has to guess it.
# Provide hints like "too high" or "too low" after each guess.
# Include a limited number of attempts and a score system based on accuracy.
#
# #### Hangman:
#
# Create a word bank and randomly select a word for the player to guess.
# Display the current state of the word with blanks for unrevealed letters.
# Allow a limited number of incorrect guesses before the game ends.
#
# #### Tic-Tac-Toe:
#
# Implement a two-player Tic-Tac-Toe game.
# Ensure proper input validation and display the game board after each move.
# Declare the winner or a draw when the game concludes.
#
# __Note: you can explore implementiong any other game of your choice.__
#
#
# ## Requirements
#
# This project has two types of requirements:
#
# ### Technical Requirements:
# Technical Requirements are designed to guide you on your project. These will help point you in the right direction as well as show you what we will be looking for when reviewing your project. These requirements will be focused towards the specific coding aspects you use.
#
# ### Functional Requirements:
# Functional Requirements are designed to provoke thought throughout your project. These will be based in theory rather than code. These requirements will assist in shaping your output of each task.
#
# #### Make sure to read the instructions thoroughly.
#
# <hr style="border:2px solid">
# <h1 style="text-align:center; font-size: 3em;">Project Requirements</h1>
# <hr style="border-top:1px dashed">
#
# ### Functional Requirements:
#
# - Use functions to modularise your code and promote code readability.
# - Implement proper error handling for user inputs to avoid crashes.
# - Ensure the game provides clear instructions and feedback to the player.
# - Add comments to explain complex sections of your code.
# - Create a README file that includes instructions on how to play the game.
# - Have statistics of the games.
#
# __Optional:__
#
# - Implement a graphical user interface (GUI) using libraries like Pygame or Tkinter.
# - Add sound effects or background music to enhance the gaming experience.
# - Create additional levels or features to make the game more challenging.
#
# ### Code Requirements:
#
# This project will require an assortment of counter variables that will have to be set on a global scale (they exist outside of all functions). It will also be required to use at least two function that you write. I would recommend you create the barebones of the game, then pretty it up. Do not worry about making incredibly detailed print statements and formatting until you finish the base game.
#
# - Provide flowchart.
# - Write at least two functions.
# - Check the user input for any types of non-numeric answers or those that are not expected by the program (when applicable).
# - Use several global counters to keep track of user's statistics.
# - Code must have comment's explaining what you did following coding style standars and documentaton best practices.
#
#
# ### Deliverables:
#
# - Flowchart.
# - Python script or Jupyter Notebook with the game.
# - GitHub Repo.
# - README file.
# - Up to 3 min video presentation sowcasing the game.
#
# ***Note on AI Use***:
# We understand that AI tools can be helpful in coding, and we do not discourage their use. However, for this project, we strongly encourage you to minimise your reliance on AI. This is a crucial stage in your learning journey, and working through the problems yourself will help you build a solid understanding of Python fundamentals. Overusing AI at this point may hinder your ability to grasp key concepts and develop problem-solving skills that are essential for your growth as a programmer.
#
#
# <hr style="border:2px solid">

# %% [markdown]
# ---
#
# ### Part One:
# > Please provide the Flowchart of your solution.
#
# > These do not need to be overly detailed. Create basic short steps.

# %% [markdown]
# ---
#
# ### Part Two:
# > Build it!
#
# > Write your code below.
#
# > Work towards a minimal viable product before working on making your output pretty.

# %%
# 1. Word bank (150 words, no repeats)
word_bank = [
    "planet", "castle", "bridge", "forest", "silver", "hunter", "puzzle", "dragon","window", "garden", "throne", "candle", "butter", "marble", "saddle", "rocket",
    "pirate", "anchor", "helmet", "shield", "wizard", "market", "fabric", "pencil","camera", "ticket", "branch", "stream", "flower", "animal", "desert", "island",
    "throat", "pocket", "button", "string", "circle", "square", "danger", "singer","writer", "reader", "doctor", "farmer", "bottle", "coffee", "cookie", "donkey",
    "rabbit", "kitten", "puppy", "parrot", "eagle", "falcon", "turtle", "shark","salmon", "pepper", "tomato", "cheese", "butter", "pickle", "banana", "orange",
    "grapes", "peach", "apples", "carrot", "potato", "onions", "garlic", "ginger","pepper", "cactus", "planet", "meteor", "galaxy", "cosmic", "rocket", "comet",
    "sunset", "sunrise", "thunder", "lighten", "stormy", "breeze", "winter", "summer","autumn", "spring", "harbor", "vessel", "bridge", "castle", "temple",
    "market","fabric", "cotton", "velvet", "leather", "rubber", "plastic", "copper", "silver","golden", "bronze", "marble", "granite", "crystal", "quartz", "jasper", 
    "onyx","velvet", "thread", "needle", "scarf", "jacket", "trousers", "sweater", "blanket","pillow", "basket", "ladder", "hammer", "chisel", "spirit", "memory", "future",
    "moment", "shadow", "bright", "silent", "noodle", "puzzle", "random", "simple","gentle", "strong", "broken", "smooth", "sticky", "crispy", "salmon", "butter"
]



# 2. IMPORTS

import random



# 3. select_word() – selects a random word

def select_word():
    '''selects a random word from the word bank'''
    return random.choice(word_bank)
#print(random.choice(word_bank))


# 4. display() – builds the _ _ _ _ blanks

def display(word):
    '''displays the _ _ _ _ to indicate the length of word'''
    return ["_"] * len(word)
word = select_word()
#print(word) 
print(display(word))


# 5. get_guess() – receives and validates player input
def get_valid_guess(guess, guessed_letters):
    '''Validates the player input to ensure it is a single new letter'''
    if len(guess) != 1:
        print("Only 1 letter at a time please")
        return False
    if not guess.isalpha():
        print("Only letters are valid inputs")
        return False
    if guess in guessed_letters:
        print("Woops, you have already guessed that")
        return False
    return True



def get_guess(guessed_letters):
    '''input for your guesseses'''
    while True:
        guess = input("your guess: ").lower().strip()
        if get_valid_guess(guess, guessed_letters):
            return guess




# 6. update_display() – fills in correct letters

def update_display(word, display, guess):
    ''' makes the word into a list of letters log each letters position and identifys the letters then checks if the guess is one of the letters'''
    # 1. makes letters into a list
    letters = list(word)

    # 2. logs letters' positions + 3. identifies if letter was in list
    for index, letter in enumerate(letters):
        
        # 4. replaces _ with letters
        if letter == guess:
            display[index] = guess

    return display


# 7. update_wrong_guesses() – tracks incorrect guesses

def update_wrong_guesses(guess, wrong_letters):
    wrong_letters.add(guess)
    '''add wrong guesses to the wrong guesses set'''
    return wrong_letters





# 8. check_win() – no blanks remain

def check_win(display):
    '''checks if there are no "_" left in the display'''
    if "_" not in display:
        return True
    else:
        return False





# 9. check_loss() – 6 incorrect guesses

    def check_loss(wrong_letters):
        '''checks if the number of wrong guesses is 6 says you have lost'''
    if len(wrong_letters) >= 6:
        return True
    else:
        return False
        
# 12. show_results() – prints statistics
def show_results(stats):
    print("\nFinal results for all players:")
    print("------------------------------")
    for name, record in stats.items():
        print(f"{name}: {record['wins']} wins, {record['losses']} losses")




# 10. play_round() – inner loop for one game

def play_round(stats):
    word = select_word()
    display_list = display(word)
    guessed_letters = set()
    wrong_letters = set()

    while True:
        # Show current progress
        print("Word:", " ".join(display_list))
        print("incorret guesses:", " ".join(sorted(wrong_letters)))

        # Get a guess
        guess = get_guess(guessed_letters)
        guessed_letters.add(guess)

        # Correct or wrong?
        if guess in word:
            update_display(word, display_list, guess)
        else:
            update_wrong_guesses(guess, wrong_letters)

        # Check win
        if check_win(display_list):
            print("You win! The word was:", word)
            stats["wins"] += 1
            break

        # Check loss
        if check_loss(wrong_letters):
            print("You lost! The word was:", word)
            stats["losses"] += 1
            break



# -----------------------------
# 11. main() – outer loop for multiple games
# -----------------------------
def main():
    stats = {}

    while True:
        name = input("What is your name? ").strip()

        if name not in stats:
            stats[name] = {"wins": 0, "losses": 0}

        play = input(f"Hello {name}, do you want to play Hangman? (y/n): ").lower()

        while play == "y":
            play_round(stats[name])
            play = input("Play again? (y/n): ").lower()

        print(f"\n{name}'s stats:")
        print(f"Wins: {stats[name]['wins']}")
        print(f"Losses: {stats[name]['losses']}")

        another = input("\nIs there another player? (y/n): ").lower()
        if another != "y":
            break

    # End of program — NOW stats exists
    show_results(stats)





# -----------------------------
# RUN THE PROGRAM
# -----------------------------
if __name__ == "__main__":
    main()
# Out:
# ['_', '_', '_', '_', '_', '_']
# What is your name?  bob
# Hello bob, do you want to play Hangman? (y/n):  y
# Word: _ _ _ _ _ _
# incorret guesses:
# your guess:  o
# Word: _ o o _ _ _
# incorret guesses:
# your guess:  1
# Only letters are valid inputs
# your guess:  po
# Only 1 letter at a time please
# your guess:  o
# Woops, you have already guessed that
# your guess:  k
# Word: _ o o k _ _
# incorret guesses:
# your guess:  t
# Word: _ o o k _ _
# incorret guesses: t
# your guess:  p
# Word: _ o o k _ _
# incorret guesses: p t
# your guess:  b
# Word: _ o o k _ _
# incorret guesses: b p t
# your guess:  h
# Word: _ o o k _ _
# incorret guesses: b h p t
# your guess:  c
# Word: c o o k _ _
# incorret guesses: b h p t
# your guess:  e
# Word: c o o k _ e
# incorret guesses: b h p t
# your guess:  o
# Woops, you have already guessed that
# your guess:  p
# Woops, you have already guessed that
# your guess:  f
# Word: c o o k _ e
# incorret guesses: b f h p t
# your guess:  w
# ...

# %%
# 1. Word bank (150 words, no repeats)
word_bank = [
    "planet", "castle", "bridge", "forest", "silver", "hunter", "puzzle", "dragon","window", "garden", "throne", "candle", "butter", "marble", "saddle", "rocket",
    "pirate", "anchor", "helmet", "shield", "wizard", "market", "fabric", "pencil","camera", "ticket", "branch", "stream", "flower", "animal", "desert", "island",
    "throat", "pocket", "button", "string", "circle", "square", "danger", "singer","writer", "reader", "doctor", "farmer", "bottle", "coffee", "cookie", "donkey",
    "rabbit", "kitten", "puppy", "parrot", "eagle", "falcon", "turtle", "shark","salmon", "pepper", "tomato", "cheese", "butter", "pickle", "banana", "orange",
    "grapes", "peach", "apples", "carrot", "potato", "onions", "garlic", "ginger","pepper", "cactus", "planet", "meteor", "galaxy", "cosmic", "rocket", "comet",
    "sunset", "sunrise", "thunder", "lighten", "stormy", "breeze", "winter", "summer","autumn", "spring", "harbor", "vessel", "bridge", "castle", "temple",
    "market","fabric", "cotton", "velvet", "leather", "rubber", "plastic", "copper", "silver","golden", "bronze", "marble", "granite", "crystal", "quartz", "jasper", 
    "onyx","velvet", "thread", "needle", "scarf", "jacket", "trousers", "sweater", "blanket","pillow", "basket", "ladder", "hammer", "chisel", "spirit", "memory", "future",
    "moment", "shadow", "bright", "silent", "noodle", "puzzle", "random", "simple","gentle", "strong", "broken", "smooth", "sticky", "crispy", "salmon", "butter"
]

HANGMAN_PICS = [
    """
       +---+
       |   |
           |
           |
           |
           |
    =========
    """,
    """
       +---+
       |   |
       O   |
           |
           |
           |
    =========
    """,
    """
       +---+
       |   |
       O   |
       |   |
           |
           |
    =========
    """,
    """
       +---+
       |   |
       O   |
      /|   |
           |
           |
    =========
    """,
    """
       +---+
       |   |
       O   |
      /|\  |
           |
           |
    =========
    """,
    """
       +---+
       |   |
       O   |
      /|\  |
      /    |
           |
    =========
    """,
    """
       +---+
       |   |
       O   |
      /|\  |
      / \  |
           |
    =========
    """
]


# 2. IMPORTS
import random

# 3. select_word() – selects a random word
def select_word():
    '''selects a random word from the word bank'''
    return random.choice(word_bank)
#print(random.choice(word_bank))

# 4. display() – builds the _ _ _ _ blanks
def display(word):
    '''displays the _ _ _ _ to indicate the length of word'''
    return ["_"] * len(word)
word = select_word()
#print(word) 
print(display(word))

# 5. get_guess() – receives and validates player input
def get_valid_guess(guess, guessed_letters):
    '''Validates the player input to ensure it is a single new letter'''
    if len(guess) != 1:
        print("Only 1 letter at a time please")
        return False
    if not guess.isalpha():
        print("Only letters are valid inputs")
        return False
    if guess in guessed_letters:
        print("Woops, you have already guessed that")
        return False
    return True



def get_guess(guessed_letters):
    '''input for your guesseses'''
    while True:
        guess = input("your guess: ").lower().strip()
        if get_valid_guess(guess, guessed_letters):
            return guess
# 6. update_display() – fills in correct letters

def update_display(word, display, guess):
    ''' makes the word into a list of letters log each letters position and identifys the letters then checks if the guess is one of the letters'''
    # 1. makes letters into a list
    letters = list(word)

    # 2. logs letters' positions + 3. identifies if letter was in list
    for index, letter in enumerate(letters):
        
        # 4. replaces _ with letters
        if letter == guess:
            display[index] = guess

    return display
    
# 7. update_wrong_guesses() – tracks incorrect guesses            
def update_wrong_guesses(guess, wrong_letters):
    wrong_letters.add(guess)
    '''add wrong guesses to the wrong guesses set'''
    return wrong_letters
    
# 8. check_win() – no blanks remain
def check_win(display):
    '''checks if there are no "_" left in the display'''
    if "_" not in display:
        return True
    else:
        return False
        
# 9. check_loss() – 6 incorrect guesses
def check_loss(wrong_letters):
    '''if full hangman showes you lose'''
    max_wrong = len(HANGMAN_PICS) - 1
    return len(wrong_letters) >= max_wrong

# 12. show_results() – prints statistics
def show_results(stats):
    print("\nFinal results for all players:")
    print("------------------------------")
    for name, record in stats.items():
        print(f"{name}: {record['wins']} wins, {record['losses']} losses")

# shows the hang man stage 
def show_hangman(wrong_count):
    '''creates the hang man picture'''
    max_index = len(HANGMAN_PICS) - 1
    index = min(wrong_count, max_index)
    print(HANGMAN_PICS[index])

# 10. play_round() – inner loop for one game
def play_round(stats):
    '''core mechanic for running game loop'''
    word = select_word()
    display_list = display(word)
    guessed_letters = set()
    wrong_letters = set()

    while True:
        show_hangman(len(wrong_letters))
        print("Word:", " ".join(display_list))
        print("Incorrect guesses:", " ".join(sorted(wrong_letters)))

        guess = get_guess(guessed_letters)
        guessed_letters.add(guess)

        if guess in word:
            update_display(word, display_list, guess)
        else:
            update_wrong_guesses(guess, wrong_letters)

        if check_win(display_list):
            print("You win! The word was:", word)
            stats["wins"] += 1
            break

        if check_loss(wrong_letters):
            show_hangman(len(wrong_letters))
            print("You lost! The word was:", word)
            stats["losses"] += 1
            break
            
# 11. main() – outer loop for multiple games
def main():
    '''runs outer loop of game '''
    stats = {}

    while True:
        name = input("What is your name? ").strip()

        if name not in stats:
            stats[name] = {"wins": 0, "losses": 0}

        play = input(f"Hello {name}, do you want to play Hangman? (y/n): ").lower()

        while play == "y":
            play_round(stats[name])
            play = input("Play again? (y/n): ").lower()

        print(f"\n{name}'s stats:")
        print(f"Wins: {stats[name]['wins']}")
        print(f"Losses: {stats[name]['losses']}")

        
        while True:
            another = input("\nIs there another player? (y/n): ").lower().strip()
            if another in ("y", "n"):
                break
            print("Invalid input. Please enter 'y' or 'n'.")

        if another == "n":
            break

    show_results(stats)

# RUN THE PROGRAM
if __name__ == "__main__":
    try:
        main()
    except Exception as e:
        print("\nAn unexpected error occurred:", e)
# Out:
# ['_', '_', '_', '_', '_', '_']
# What is your name?  ben
# Hello ben, do you want to play Hangman? (y/n):  y
#        +---+
#        |   |
#            |
#            |
#            |
#            |
# ...
#
# Word: _ _ _ _ _ _
# Incorrect guesses:
# your guess:  i
#        +---+
#        |   |
#            |
#            |
#            |
#            |
# ...
#
# Word: _ i _ _ _ _
# Incorrect guesses:
# your guess:  a
#        +---+
#        |   |
#        O   |
#            |
#            |
#            |
# ...
#
# Word: _ i _ _ _ _
# Incorrect guesses: a
# your guess:  e
#        +---+
#        |   |
#        O   |
#            |
#            |
#            |
# ...
#
# Word: _ i _ _ _ e
# Incorrect guesses: a
# your guess:  c
#        +---+
#        |   |
#        O   |
#            |
#            |
#            |
# ...
#
# Word: c i _ c _ e
# Incorrect guesses: a
# your guess:  r
#        +---+
#        |   |
#        O   |
#            |
#            |
#            |
# ...
#
# Word: c i r c _ e
# ...

# %%
# 1. Word bank (150 words, no repeats)
word_bank = [
    "planet", "castle", "bridge", "forest", "silver", "hunter", "puzzle", "dragon","window", "garden", "throne", "candle", "butter", "marble", "saddle", "rocket",
    "pirate", "anchor", "helmet", "shield", "wizard", "market", "fabric", "pencil","camera", "ticket", "branch", "stream", "flower", "animal", "desert", "island",
    "throat", "pocket", "button", "string", "circle", "square", "danger", "singer","writer", "reader", "doctor", "farmer", "bottle", "coffee", "cookie", "donkey",
    "rabbit", "kitten", "puppy", "parrot", "eagle", "falcon", "turtle", "shark","salmon", "pepper", "tomato", "cheese", "butter", "pickle", "banana", "orange",
    "grapes", "peach", "apples", "carrot", "potato", "onions", "garlic", "ginger","pepper", "cactus", "planet", "meteor", "galaxy", "cosmic", "rocket", "comet",
    "sunset", "sunrise", "thunder", "lighten", "stormy", "breeze", "winter", "summer","autumn", "spring", "harbor", "vessel", "bridge", "castle", "temple",
    "market","fabric", "cotton", "velvet", "leather", "rubber", "plastic", "copper", "silver","golden", "bronze", "marble", "granite", "crystal", "quartz", "jasper", 
    "onyx","velvet", "thread", "needle", "scarf", "jacket", "trousers", "sweater", "blanket","pillow", "basket", "ladder", "hammer", "chisel", "spirit", "memory", "future",
    "moment", "shadow", "bright", "silent", "noodle", "puzzle", "random", "simple","gentle", "strong", "broken", "smooth", "sticky", "crispy", "salmon", "butter"
]

HANGMAN_PICS = [
    """
       +---+
       |   |
           |
           |
           |
           |
    =========
    """,
    """
       +---+
       |   |
       O   |
           |
           |
           |
    =========
    """,
    """
       +---+
       |   |
       O   |
       |   |
           |
           |
    =========
    """,
    """
       +---+
       |   |
       O   |
      /|   |
           |
           |
    =========
    """,
    """
       +---+
       |   |
       O   |
      /|\  |
           |
           |
    =========
    """,
    """
       +---+
       |   |
       O   |
      /|\  |
      /    |
           |
    =========
    """,
    """
       +---+
       |   |
       O   |
      /|\  |
      / \  |
           |
    =========
    """
]


# 2. IMPORTS
import random



# 3. select_word() – selects a random word
def select_word():
    '''selects a random word from the word bank'''
    return random.choice(word_bank)
#print(random.choice(word_bank))


# 4. display() – builds the _ _ _ _ blanks
def display(word):
    '''displays the _ _ _ _ to indicate the length of word'''
    return ["_"] * len(word)
word = select_word()
#print(word) 
print(display(word))


# 5. get_guess() – receives and validates player input
def get_valid_guess(guess, guessed_letters):
    '''Validates the player input to ensure it is a single new letter'''
    if len(guess) != 1:
        print("Only 1 letter at a time please")
        return False
    if not guess.isalpha():
        print("Only letters are valid inputs")
        return False
    if guess in guessed_letters:
        print("Woops, you have already guessed that")
        return False
    return True

def get_guess(guessed_letters):
    '''input for your guesseses'''
    while True:
        guess = input("your guess: ").lower().strip()
        if get_valid_guess(guess, guessed_letters):
            return guess




# 6. update_display() – fills in correct letters
def update_display(word, display, guess):
    ''' makes the word into a list of letters log each letters position and identifys the letters then checks if the guess is one of the letters'''
    # 1. makes letters into a list
    letters = list(word)

    # 2. logs letters' positions + 3. identifies if letter was in list
    for index, letter in enumerate(letters):
        
        # 4. replaces _ with letters
        if letter == guess:
            display[index] = guess

    return display

# 7. update_wrong_guesses() – tracks incorrect guesses
def update_wrong_guesses(guess, wrong_letters):
    wrong_letters.add(guess)
    '''add wrong guesses to the wrong guesses set'''
    return wrong_letters

# 8. check_win() – no blanks remain
def check_win(display):
    '''checks if there are no "_" left in the display'''
    if "_" not in display:
        return True
    else:
        return False

# 9. check_loss() – 6 incorrect guesses
def check_loss(wrong_letters):
    '''if full hangman showes you lose'''
    max_wrong = len(HANGMAN_PICS) - 1
    return len(wrong_letters) >= max_wrong

        
# 12. show_results() – prints statistics
def show_results(stats):
    print("\nFinal results for all players:")
    print("------------------------------")
    for name, record in stats.items():
        print(f"{name}: {record['wins']} wins, {record['losses']} losses")


# shows the hang man stage 
def show_hangman(wrong_count):
    '''creates the hang man picture'''
    max_index = len(HANGMAN_PICS) - 1
    index = min(wrong_count, max_index)
    print(HANGMAN_PICS[index])




# 10. play_round() – inner loop for one game
def play_round(stats):
    '''core mechanic for running game loop'''
    word = select_word()
    display_list = display(word)
    guessed_letters = set()
    wrong_letters = set()

    while True:
        show_hangman(len(wrong_letters))
        print("Word:", " ".join(display_list))
        print("Incorrect guesses:", " ".join(sorted(wrong_letters)))

        guess = get_guess(guessed_letters)
        guessed_letters.add(guess)

        if guess in word:
            update_display(word, display_list, guess)
        else:
            update_wrong_guesses(guess, wrong_letters)

        if check_win(display_list):
            print("You win! The word was:", word)
            stats["wins"] += 1
            break

        if check_loss(wrong_letters):
            show_hangman(len(wrong_letters))
            print("You lost! The word was:", word)
            stats["losses"] += 1
            break

# 11. main() – outer loop for multiple games
def main():
    '''runs outer loop of game '''
    stats = {}

    while True:
        name = input("What is your name? ").strip().lower()

        if name not in stats:
            stats[name] = {"wins": 0, "losses": 0}

        play = input(f"Hello {name}, do you want to play Hangman? (y/n): ").lower()

        while play == "y":
            play_round(stats[name])
            play = input("Play again? (y/n): ").lower()

        print(f"\n{name}'s stats:")
        print(f"Wins: {stats[name]['wins']}")
        print(f"Losses: {stats[name]['losses']}")

        
        while True:
            another = input("\nIs there another player? (y/n): ").lower().strip()
            if another in ("y", "n"):
                break
            print("Invalid input. Please enter 'y' or 'n'.")

        if another == "n":
            break

    show_results(stats)

# RUN THE PROGRAM
if __name__ == "__main__":
    try:
        main()
    except Exception as e:
        print("\nAn unexpected error occurred:", e)
# Out:
# ['_', '_', '_', '_', '_', '_']
# What is your name?  hi
# Hello hi, do you want to play Hangman? (y/n):  y
#        +---+
#        |   |
#            |
#            |
#            |
#            |
# ...
#
# Word: _ _ _ _ _
# Incorrect guesses:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[57], line 248
#     246 if __name__ == "__main__":
#     247     try:
# --> 248         main()
#     249     except Exception as e:
#     250         print("\nAn unexpected error occurred:", e)
#
# Cell In[57], line 226, in main()
#     223 play = input(f"Hello {name}, do you want to play Hangman? (y/n): ").lower()
#     225 while play == "y":
# --> 226     play_round(stats[name])
#     227     play = input("Play again? (y/n): ").lower()
#     229 print(f"\n{name}'s stats:")
#
# Cell In[57], line 193, in play_round(stats)
#     190 print("Word:", " ".join(display_list))
# ...

# %%
# 1. Word bank (150 words, no repeats)
word_bank = [
    "planet", "castle", "bridge", "forest", "silver", "hunter", "puzzle", "dragon","window", "garden", "throne", "candle", "butter", "marble", "saddle", "rocket",
    "pirate", "anchor", "helmet", "shield", "wizard", "market", "fabric", "pencil","camera", "ticket", "branch", "stream", "flower", "animal", "desert", "island",
    "throat", "pocket", "button", "string", "circle", "square", "danger", "singer","writer", "reader", "doctor", "farmer", "bottle", "coffee", "cookie", "donkey",
    "rabbit", "kitten", "puppy", "parrot", "eagle", "falcon", "turtle", "shark","salmon", "pepper", "tomato", "cheese", "butter", "pickle", "banana", "orange",
    "grapes", "peach", "apples", "carrot", "potato", "onions", "garlic", "ginger","pepper", "cactus", "planet", "meteor", "galaxy", "cosmic", "rocket", "comet",
    "sunset", "sunrise", "thunder", "lighten", "stormy", "breeze", "winter", "summer","autumn", "spring", "harbor", "vessel", "bridge", "castle", "temple",
    "market","fabric", "cotton", "velvet", "leather", "rubber", "plastic", "copper", "silver","golden", "bronze", "marble", "granite", "crystal", "quartz", "jasper", 
    "onyx","velvet", "thread", "needle", "scarf", "jacket", "trousers", "sweater", "blanket","pillow", "basket", "ladder", "hammer", "chisel", "spirit", "memory", "future",
    "moment", "shadow", "bright", "silent", "noodle", "puzzle", "random", "simple","gentle", "strong", "broken", "smooth", "sticky", "crispy", "salmon", "butter"
]

HANGMAN_PICS = [
    """
       +---+
       |   |
           |
           |
           |
           |
    =========
    """,
    """
       +---+
       |   |
       O   |
           |
           |
           |
    =========
    """,
    """
       +---+
       |   |
       O   |
       |   |
           |
           |
    =========
    """,
    """
       +---+
       |   |
       O   |
      /|   |
           |
           |
    =========
    """,
    """
       +---+
       |   |
       O   |
      /|\  |
           |
           |
    =========
    """,
    """
       +---+
       |   |
       O   |
      /|\  |
      /    |
           |
    =========
    """,
    """
       +---+
       |   |
       O   |
      /|\  |
      / \  |
           |
    =========
    """
]


# 2. IMPORTS
import random



# 3. select_word() – selects a random word
def select_word():
    '''selects a random word from the word bank'''
    return random.choice(word_bank)
#print(random.choice(word_bank))


# 4. display() – builds the _ _ _ _ blanks
def display(word):
    '''displays the _ _ _ _ to indicate the length of word'''
    return ["_"] * len(word)
word = select_word()
#print(word) 
print(display(word))


# 5. get_guess() – receives and validates player input
def get_valid_guess(guess, guessed_letters):
    '''Validates the player input to ensure it is a single new letter'''
    if len(guess) != 1:
        print("Only 1 letter at a time please")
        return False
    if not guess.isalpha():
        print("Only letters are valid inputs")
        return False
    if guess in guessed_letters:
        print("Woops, you have already guessed that")
        return False
    return True

def get_guess(guessed_letters):
    '''input for your guesseses'''
    while True:
        guess = input("your guess: ").lower().strip()
        if get_valid_guess(guess, guessed_letters):
            return guess




# 6. update_display() – fills in correct letters
def update_display(word, display, guess):
    ''' makes the word into a list of letters log each letters position and identifys the letters then checks if the guess is one of the letters'''
    # 1. makes letters into a list
    letters = list(word)

    # 2. logs letters' positions + 3. identifies if letter was in list
    for index, letter in enumerate(letters):
        
        # 4. replaces _ with letters
        if letter == guess:
            display[index] = guess

    return display

# 7. update_wrong_guesses() – tracks incorrect guesses
def update_wrong_guesses(guess, wrong_letters):
    wrong_letters.add(guess)
    '''add wrong guesses to the wrong guesses set'''
    return wrong_letters

# 8. check_win() – no blanks remain
def check_win(display):
    '''checks if there are no "_" left in the display'''
    if "_" not in display:
        return True
    else:
        return False

# 9. check_loss() – 6 incorrect guesses
def check_loss(wrong_letters):
    '''if full hangman showes you lose'''
    max_wrong = len(HANGMAN_PICS) - 1
    return len(wrong_letters) >= max_wrong

        
# 12. show_results() – prints statistics
def show_results(stats):
    '''prints the game stats'''
    print("\nFinal results for all players:")
    print("------------------------------")
    for name, record in stats.items():
        print(
            f"{name}: {record['wins']} wins, {record['losses']} losses, "
            f"{record['correct']} correct guesses, {record['incorrect']} incorrect guesses" )



# shows the hang man stage 
def show_hangman(wrong_count):
    '''creates the hang man picture'''
    max_index = len(HANGMAN_PICS) - 1
    index = min(wrong_count, max_index)
    print(HANGMAN_PICS[index])

# 10. play_round() – inner loop for one game
def play_round(stats):
    '''core mechanic for running game loop'''
    word = select_word()
    display_list = display(word)
    guessed_letters = set()
    wrong_letters = set()
    correct_guesses = 0
    incorrect_guesses = 0

    while True:
        show_hangman(len(wrong_letters))
        print("Word:", " ".join(display_list))
        print("Incorrect guesses:", " ".join(sorted(wrong_letters)))

        guess = get_guess(guessed_letters)
        guessed_letters.add(guess)

        #point system for the guesses
        if guess in word:
            update_display(word, display_list, guess)
            correct_guesses += 1
        else:
            update_wrong_guesses(guess, wrong_letters)
            incorrect_guesses += 1
            
        #poit sytem for wins and losses
        
        if check_win(display_list):
            print("You win! The word was:", word)
            print(f"Correct guesses this round: {correct_guesses}")
            print(f"Incorrect guesses this round: {incorrect_guesses}")
            
            stats["wins"] += 1
            stats["correct"] += correct_guesses
            stats["incorrect"] += incorrect_guesses
            break
                
        if check_loss(wrong_letters):
            show_hangman(len(wrong_letters))
            print("You lost! The word was:", word)
            print(f"Correct guesses this round: {correct_guesses}")
            print(f"Incorrect guesses this round: {incorrect_guesses}")
        
            stats["losses"] += 1
            stats["correct"] += correct_guesses
            stats["incorrect"] += incorrect_guesses
            break


# 11. main() – outer loop for multiple games
def main():
    '''Run the full Hangman game, including multiple players and rounds. Handles player setup, input validation, game loops, and final results.'''
    stats = {}

    while True:
        name = input("What is your name? ").strip()
        if name:  # not empty after stripping spaces
            name = name.lower()
            break
        print("Invalid name. Please enter at least one character.")

        #creates stat dictonary
        if name not in stats:
            stats[name] = {
                "wins": 0,
                "losses": 0,
                "correct": 0,
                "incorrect": 0}


        # Validate play input
        while True:
            play = input(f"Hello {name}, do you want to play Hangman? (y/n): ").lower().strip()
            if play in ("y", "n"):
                break
            print("Invalid input. Please enter 'y' or 'n'.")

        # Play rounds
        while play == "y":
            play_round(stats[name])

            # Validate play again input
            while True:
                play = input("Play again? (y/n): ").lower().strip()
                if play in ("y", "n"):
                    break
                print("Invalid input. Please enter 'y' or 'n'.")

        # Show stats for this player
        print(f"\n{name}'s stats:")
        print(f"Wins: {stats[name]['wins']}")
        print(f"Losses: {stats[name]['losses']}")

        # Validate another player input
        while True:
            another = input("\nIs there another player? (y/n): ").lower().strip()
            if another in ("y", "n"):
                break
            print("Invalid input. Please enter 'y' or 'n'.")

        if another == "n":
            break


    show_results(stats)

# RUN THE PROGRAM
if __name__ == "__main__":
    try:
        main()
    except Exception as e:
        print("\nAn unexpected error occurred:", e)


#Add consistent docstrings

#Add comments to complex logic

#Add correct/incorrect guess stats to lifetime totals

#Improve naming clarity

#Add user feedback messages

#Ensure all input validation loops are consistent#
# Out:
# ['_', '_', '_', '_', '_', '_']
# What is your name?  hi
# Final results for all players:
# ------------------------------

# %%
try:
        # 1. Word bank (150 words, no repeats)
    word_bank = [
        "planet", "castle", "bridge", "forest", "silver", "hunter", "puzzle", "dragon","window", "garden", "throne", "candle", "butter", "marble", "saddle", "rocket",
        "pirate", "anchor", "helmet", "shield", "wizard", "market", "fabric", "pencil","camera", "ticket", "branch", "stream", "flower", "animal", "desert", "island",
        "throat", "pocket", "button", "string", "circle", "square", "danger", "singer","writer", "reader", "doctor", "farmer", "bottle", "coffee", "cookie", "donkey",
        "rabbit", "kitten", "puppy", "parrot", "eagle", "falcon", "turtle", "shark","salmon", "pepper", "tomato", "cheese", "butter", "pickle", "banana", "orange",
        "grapes", "peach", "apples", "carrot", "potato", "onions", "garlic", "ginger","pepper", "cactus", "planet", "meteor", "galaxy", "cosmic", "rocket", "comet",
        "sunset", "sunrise", "thunder", "lighten", "stormy", "breeze", "winter", "summer","autumn", "spring", "harbor", "vessel", "bridge", "castle", "temple",
        "market","fabric", "cotton", "velvet", "leather", "rubber", "plastic", "copper", "silver","golden", "bronze", "marble", "granite", "crystal", "quartz", "jasper", 
        "onyx","velvet", "thread", "needle", "scarf", "jacket", "trousers", "sweater", "blanket","pillow", "basket", "ladder", "hammer", "chisel", "spirit", "memory", "future",
        "moment", "shadow", "bright", "silent", "noodle", "puzzle", "random", "simple","gentle", "strong", "broken", "smooth", "sticky", "crispy", "salmon", "butter"
    ]
    
    HANGMAN_PICS = [
        """
           +---+
           |   |
               |
               |
               |
               |
        =========
        """,
        """
           +---+
           |   |
           O   |
               |
               |
               |
        =========
        """,
        """
           +---+
           |   |
           O   |
           |   |
               |
               |
        =========
        """,
        """
           +---+
           |   |
           O   |
          /|   |
               |
               |
        =========
        """,
        """
           +---+
           |   |
           O   |
          /|\  |
               |
               |
        =========
        """,
        """
           +---+
           |   |
           O   |
          /|\  |
          /    |
               |
        =========
        """,
        """
           +---+
           |   |
           O   |
          /|\  |
          / \  |
               |
        =========
        """
    ]
    
    
    # 2. IMPORTS
    import random
    
    
    
    # 3. select_word() – selects a random word
    def select_word():
        '''selects a random word from the word bank'''
        return random.choice(word_bank)
    #print(random.choice(word_bank))
    
    
    # 4. display() – builds the _ _ _ _ blanks
    def display(word):
        '''displays the _ _ _ _ to indicate the length of word'''
        return ["_"] * len(word)
    word = select_word()
    #print(word) 
    print(display(word))
    
    
    # 5. get_guess() – receives and validates player input
    def get_valid_guess(guess, guessed_letters):
        '''Validates the player input to ensure it is a single new letter'''
        if len(guess) != 1:
            print("Only 1 letter at a time please")
            return False
        if not guess.isalpha():
            print("Only letters are valid inputs")
            return False
        if guess in guessed_letters:
            print("Woops, you have already guessed that")
            return False
        return True
    
    def get_guess(guessed_letters):
        '''input for your guesseses'''
        while True:
            guess = input("your guess: ").lower().strip()
            if get_valid_guess(guess, guessed_letters):
                return guess
    
    
    # 6. update_display() – fills in correct letters
    def update_display(word, display, guess):
        ''' makes the word into a list of letters log each letters position and identifys the letters then checks if the guess is one of the letters'''
        # 1. makes letters into a list
        letters = list(word)
    
        # 2. logs letters' positions + 3. identifies if letter was in list
        for index, letter in enumerate(letters):
            
            # 4. replaces _ with letters
            if letter == guess:
                display[index] = guess
    
        return display
    
    # 7. update_wrong_guesses() – tracks incorrect guesses
    def update_wrong_guesses(guess, wrong_letters):
        wrong_letters.add(guess)
        '''add wrong guesses to the wrong guesses set'''
        return wrong_letters
    
    # 8. check_win() – no blanks remain
    def check_win(display):
        '''checks if there are no "_" left in the display'''
        if "_" not in display:
            return True
        else:
            return False
    
    # 9. check_loss() – 6 incorrect guesses
    def check_loss(wrong_letters):
        '''if full hangman showes you lose'''
        max_wrong = len(HANGMAN_PICS) - 1
        return len(wrong_letters) >= max_wrong
    
            
    # 12. show_results() – prints statistics
    def show_results(stats):
        '''prints the game stats'''
        print("\nFinal results for all players:")
        print("------------------------------")
        for name, record in stats.items():
            print(
                f"{name}: {record['wins']} wins, {record['losses']} losses, "
                f"{record['correct']} correct guesses, {record['incorrect']} incorrect guesses" )
    
    
    
    # shows the hang man stage 
    def show_hangman(wrong_count):
        '''creates the hang man picture'''
        max_index = len(HANGMAN_PICS) - 1
        index = min(wrong_count, max_index)
        print(HANGMAN_PICS[index])
    
    # 10. play_round() – inner loop for one game
    def play_round(stats):
        '''core mechanic for running game loop'''
        word = select_word()
        display_list = display(word)
        guessed_letters = set()
        wrong_letters = set()
        correct_guesses = 0
        incorrect_guesses = 0
    
        while True:
            show_hangman(len(wrong_letters))
            print("Word:", " ".join(display_list))
            print("Incorrect guesses:", " ".join(sorted(wrong_letters)))
    
            guess = get_guess(guessed_letters)
            guessed_letters.add(guess)
    
            #point system for the guesses
            if guess in word:
                update_display(word, display_list, guess)
                correct_guesses += 1
            else:
                update_wrong_guesses(guess, wrong_letters)
                incorrect_guesses += 1
                
            #poit sytem for wins and losses
            
            if check_win(display_list):
                print("You win! The word was:", word)
                print(f"Correct guesses this round: {correct_guesses}")
                print(f"Incorrect guesses this round: {incorrect_guesses}")
                
                stats["wins"] += 1
                stats["correct"] += correct_guesses
                stats["incorrect"] += incorrect_guesses
                break
                    
            if check_loss(wrong_letters):
                show_hangman(len(wrong_letters))
                print("You lost! The word was:", word)
                print(f"Correct guesses this round: {correct_guesses}")
                print(f"Incorrect guesses this round: {incorrect_guesses}")
            
                stats["losses"] += 1
                stats["correct"] += correct_guesses
                stats["incorrect"] += incorrect_guesses
                break
    
    
    # 11. main() – outer loop for multiple games
       def main():
        """Run the full Hangman game, including multiple players and rounds."""
        stats = {}
    
        while True:
            # Ask for name with validation
            while True:
                name = input("What is your name? ").strip()
                if name:
                    name = name.lower()
                    break
                print("Invalid name. Please enter at least one character.")
    
            # Create stats entry if new player
            if name not in stats:
                stats[name] = {
                    "wins": 0,
                    "losses": 0,
                    "correct": 0,
                    "incorrect": 0
                }
    
            # Ask to play
            while True:
                play = input(f"Hello {name}, do you want to play Hangman? (y/n): ").lower().strip()
                if play in ("y", "n"):
                    break
                print("Invalid input. Please enter 'y' or 'n'.")
    
            # Play rounds
            while play == "y":
                play_round(stats[name])
    
                while True:
                    play = input("Play again? (y/n): ").lower().strip()
                    if play in ("y", "n"):
                        break
                    print("Invalid input. Please enter 'y' or 'n'.")
    
            # Show stats for this player
            print(f"\n{name}'s stats:")
            print(f"Wins: {stats[name]['wins']}")
            print(f"Losses: {stats[name]['losses']}")
    
            # Another player?
            while True:
                another = input("\nIs there another player? (y/n): ").lower().strip()
                if another in ("y", "n"):
                    break
                print("Invalid input. Please enter 'y' or 'n'.")
    
            if another == "n":
                break
    
        show_results(stats)

    
    # RUN THE PROGRAM
    if __name__ == "__main__":
        main()
        
    
except Exception as e: 
    print("\nAn unexpected error occurred:", e)
    #Add consistent docstrings
    
    #Add comments to complex logic
    
    #Add correct/incorrect guess stats to lifetime totals
    
    #Improve naming clarity
    
    #Add user feedback messages
    
    #Ensure all input validation loops are consistent
#this is broken
# Out:
#   File <string>:231
#     def main():
#                ^
# IndentationError: unindent does not match any outer indentation level

# %%
# 1. Word bank (150 words, no repeats)
word_bank = [
    "planet", "castle", "bridge", "forest", "silver", "hunter", "puzzle", "dragon","window", "garden", "throne", "candle", "butter", "marble", "saddle", "rocket",
    "pirate", "anchor", "helmet", "shield", "wizard", "market", "fabric", "pencil","camera", "ticket", "branch", "stream", "flower", "animal", "desert", "island",
    "throat", "pocket", "button", "string", "circle", "square", "danger", "singer","writer", "reader", "doctor", "farmer", "bottle", "coffee", "cookie", "donkey",
    "rabbit", "kitten", "puppy", "parrot", "eagle", "falcon", "turtle", "shark","salmon", "pepper", "tomato", "cheese", "butter", "pickle", "banana", "orange",
    "grapes", "peach", "apples", "carrot", "potato", "onions", "garlic", "ginger","pepper", "cactus", "planet", "meteor", "galaxy", "cosmic", "rocket", "comet",
    "sunset", "sunrise", "thunder", "lighten", "stormy", "breeze", "winter", "summer","autumn", "spring", "harbor", "vessel", "bridge", "castle", "temple",
    "market","fabric", "cotton", "velvet", "leather", "rubber", "plastic", "copper", "silver","golden", "bronze", "marble", "granite", "crystal", "quartz", "jasper", 
    "onyx","velvet", "thread", "needle", "scarf", "jacket", "trousers", "sweater", "blanket","pillow", "basket", "ladder", "hammer", "chisel", "spirit", "memory", "future",
    "moment", "shadow", "bright", "silent", "noodle", "puzzle", "random", "simple","gentle", "strong", "broken", "smooth", "sticky", "crispy", "salmon", "butter"
]

HANGMAN_PICS = [
    """
       +---+
       |   |
           |
           |
           |
           |
    =========
    """,
    """
       +---+
       |   |
       O   |
           |
           |
           |
    =========
    """,
    """
       +---+
       |   |
       O   |
       |   |
           |
           |
    =========
    """,
    """
       +---+
       |   |
       O   |
      /|   |
           |
           |
    =========
    """,
    """
       +---+
       |   |
       O   |
      /|\  |
           |
           |
    =========
    """,
    """
       +---+
       |   |
       O   |
      /|\  |
      /    |
           |
    =========
    """,
    """
       +---+
       |   |
       O   |
      /|\  |
      / \  |
           |
    =========
    """
]

# 2. IMPORTS
import random

# 3. select_word() – selects a random word
def select_word():
    '''selects a random word from the word bank'''
    return random.choice(word_bank)

# 4. display() – builds the _ _ _ _ blanks
def display(word):
    '''displays the _ _ _ _ to indicate the length of word'''
    return ["_"] * len(word)

# 5. get_guess() – receives and validates player input
def get_valid_guess(guess, guessed_letters):
    '''Validates the player input to ensure it is a single new letter'''
    if len(guess) != 1:
        print("Only 1 letter at a time please")
        return False
    if not guess.isalpha():
        print("Only letters are valid inputs")
        return False
    if guess in guessed_letters:
        print("Woops, you have already guessed that")
        return False
    return True

def get_guess(guessed_letters):
    '''input for your guesseses'''
    while True:
        guess = input("your guess: ").lower().strip()
        if get_valid_guess(guess, guessed_letters):
            return guess

# 6. update_display() – fills in correct letters
def update_display(word, display_list, guess):
    ''' makes the word into a list of letters log each letters position and identifys the letters then checks if the guess is one of the letters'''
    for index, letter in enumerate(word):
        if letter == guess:
            display_list[index] = guess
    return display_list

# 7. update_wrong_guesses() – tracks incorrect guesses
def update_wrong_guesses(guess, wrong_letters):
    wrong_letters.add(guess)
    '''add wrong guesses to the wrong guesses set'''
    return wrong_letters

# 8. check_win() – no blanks remain
def check_win(display_list):
    '''checks if there are no "_" left in the display'''
    return "_" not in display_list

# 9. check_loss() – 6 incorrect guesses
def check_loss(wrong_letters):
    '''if full hangman showes you lose'''
    max_wrong = len(HANGMAN_PICS) - 1
    return len(wrong_letters) >= max_wrong

# 12. show_results() – prints statistics
def show_results(stats):
    '''prints the game stats'''
    print("\nFinal results for all players:")
    print("------------------------------")
    for name, record in stats.items():
        print(
            f"{name}: {record['wins']} wins, {record['losses']} losses, "
            f"{record['correct']} correct guesses, {record['incorrect']} incorrect guesses"
        )

# shows the hang man stage 
def show_hangman(wrong_count):
    '''creates the hang man picture'''
    index = min(wrong_count, len(HANGMAN_PICS) - 1)
    print(HANGMAN_PICS[index])

# 10. play_round() – inner loop for one game
def play_round(stats):
    '''core mechanic for running game loop'''
    word = select_word()
    display_list = display(word)
    guessed_letters = set()
    wrong_letters = set()
    correct_guesses = 0
    incorrect_guesses = 0

    while True:
        show_hangman(len(wrong_letters))
        print("Word:", " ".join(display_list))
        print("Incorrect guesses:", " ".join(sorted(wrong_letters)))

        guess = get_guess(guessed_letters)
        guessed_letters.add(guess)

        #point system for the guesses
        if guess in word:
            update_display(word, display_list, guess)
            correct_guesses += 1
        else:
            update_wrong_guesses(guess, wrong_letters)
            incorrect_guesses += 1

        #poit sytem for wins and losses
        if check_win(display_list):
            print("You win! The word was:", word)
            print(f"Correct guesses this round: {correct_guesses}")
            print(f"Incorrect guesses this round: {incorrect_guesses}")

            stats["wins"] += 1
            stats["correct"] += correct_guesses
            stats["incorrect"] += incorrect_guesses
            break

        if check_loss(wrong_letters):
            show_hangman(len(wrong_letters))
            print("You lost! The word was:", word)
            print(f"Correct guesses this round: {correct_guesses}")
            print(f"Incorrect guesses this round: {incorrect_guesses}")

            stats["losses"] += 1
            stats["correct"] += correct_guesses
            stats["incorrect"] += incorrect_guesses
            break

# 11. main() – outer loop for multiple games
def main():
    '''Run the full Hangman game, including multiple players and rounds. Handles player setup, input validation, game loops, and final results.'''
    stats = {}

    while True:
        # Ask for name with validation
        while True:
            name = input("What is your name? ").strip()
            if name:
                name = name.lower()
                break
            print("Invalid name. Please enter at least one character.")

        #creates stat dictonary
        if name not in stats:
            stats[name] = {
                "wins": 0,
                "losses": 0,
                "correct": 0,
                "incorrect": 0
            }

        # Validate play input
        while True:
            play = input(f"Hello {name}, do you want to play Hangman? (y/n): ").lower().strip()
            if play in ("y", "n"):
                break
            print("Invalid input. Please enter 'y' or 'n'.")

        # Play rounds
        while play == "y":
            play_round(stats[name])

            # Validate play again input
            while True:
                play = input("Play again? (y/n): ").lower().strip()
                if play in ("y", "n"):
                    break
                print("Invalid input. Please enter 'y' or 'n'.")

        # Show stats for this player
        print(f"\n{name}'s stats:")
        print(f"Wins: {stats[name]['wins']}")
        print(f"Losses: {stats[name]['losses']}")

        # Validate another player input
        while True:
            another = input("\nIs there another player? (y/n): ").lower().strip()
            if another in ("y", "n"):
                break
            print("Invalid input. Please enter 'y' or 'n'.")

        if another == "n":
            break

    show_results(stats)

# RUN THE PROGRAM (with try wrapper for marks)
if __name__ == "__main__":
    try:
        main()
    except Exception as e:
        print("\nAn unexpected error occurred:", e)
        #Add consistent docstrings
        #Add comments to complex logic
        #Add correct/incorrect guess stats to lifetime totals
        #Improve naming clarity
        #Add user feedback messages
        #Ensure all input validation loops are consistent
# Out:
# What is your name?  hi
# Hello hi, do you want to play Hangman? (y/n):  y
#        +---+
#        |   |
#            |
#            |
#            |
#            |
# ...
#
# Word: _ _ _ _ _ _
# Incorrect guesses:
# your guess:  h
#        +---+
#        |   |
#        O   |
#            |
#            |
#            |
# ...
#
# Word: _ _ _ _ _ _
# Incorrect guesses: h
# your guess:  o
#        +---+
#        |   |
#        O   |
#        |   |
#            |
#            |
# ...
#
# Word: _ _ _ _ _ _
# Incorrect guesses: h o
# your guess:  u
#        +---+
#        |   |
#        O   |
#        |   |
#            |
#            |
# ...
#
# Word: _ u _ _ _ _
# Incorrect guesses: h o
# your guess:  i
#        +---+
#        |   |
#        O   |
#       /|   |
#            |
#            |
# ...
#
# Word: _ u _ _ _ _
# Incorrect guesses: h i o
# your guess:  a
#        +---+
#        |   |
#        O   |
#       /|\  |
#            |
#            |
# ...
#
# Word: _ u _ _ _ _
# Incorrect guesses: a h i o
# your guess:  e
# ...

# %%
# 1. Word bank (150 words, no repeats)
word_bank = [
    "planet", "castle", "bridge", "forest", "silver", "hunter", "puzzle", "dragon","window", "garden", "throne", "candle", "butter", "marble", "saddle", "rocket",
    "pirate", "anchor", "helmet", "shield", "wizard", "market", "fabric", "pencil","camera", "ticket", "branch", "stream", "flower", "animal", "desert", "island",
    "throat", "pocket", "button", "string", "circle", "square", "danger", "singer","writer", "reader", "doctor", "farmer", "bottle", "coffee", "cookie", "donkey",
    "rabbit", "kitten", "puppy", "parrot", "eagle", "falcon", "turtle", "shark","salmon", "pepper", "tomato", "cheese", "butter", "pickle", "banana", "orange",
    "grapes", "peach", "apples", "carrot", "potato", "onions", "garlic", "ginger","pepper", "cactus", "planet", "meteor", "galaxy", "cosmic", "rocket", "comet",
    "sunset", "sunrise", "thunder", "lighten", "stormy", "breeze", "winter", "summer","autumn", "spring", "harbor", "vessel", "bridge", "castle", "temple",
    "market","fabric", "cotton", "velvet", "leather", "rubber", "plastic", "copper", "silver","golden", "bronze", "marble", "granite", "crystal", "quartz", "jasper", 
    "onyx","velvet", "thread", "needle", "scarf", "jacket", "trousers", "sweater", "blanket","pillow", "basket", "ladder", "hammer", "chisel", "spirit", "memory", "future",
    "moment", "shadow", "bright", "silent", "noodle", "puzzle", "random", "simple","gentle", "strong", "broken", "smooth", "sticky", "crispy", "salmon", "butter"
]

HANGMAN_PICS = [
    """
       +---+
       |   |
           |
           |
           |
           |
    =========
    """,
    """
       +---+
       |   |
       O   |
           |
           |
           |
    =========
    """,
    """
       +---+
       |   |
       O   |
       |   |
           |
           |
    =========
    """,
    """
       +---+
       |   |
       O   |
      /|   |
           |
           |
    =========
    """,
    """
       +---+
       |   |
       O   |
      /|\  |
           |
           |
    =========
    """,
    """
       +---+
       |   |
       O   |
      /|\  |
      /    |
           |
    =========
    """,
    """
       +---+
       |   |
       O   |
      /|\  |
      / \  |
           |
    =========
    """
]

# 2. IMPORTS
import random

# Pluralisation helper
def pluralise(count, singular, plural=None):
    """Return the correct singular or plural form based on the count."""
    if count == 1:
        return singular
    return plural if plural else singular + "s"

# 3. select_word() – selects a random word
def select_word():
    '''selects a random word from the word bank'''
    return random.choice(word_bank)

# 4. display() – builds the _ _ _ _ blanks
def display(word):
    '''displays the _ _ _ _ to indicate the length of word'''
    return ["_"] * len(word)

# 5. get_guess() – receives and validates player input
def get_valid_guess(guess, guessed_letters):
    '''Validates the player input to ensure it is a single new letter'''
    if len(guess) != 1:
        print("Only 1 letter at a time please")
        return False
    if not guess.isalpha():
        print("Only letters are valid inputs")
        return False
    if guess in guessed_letters:
        print("Woops, you have already guessed that")
        return False
    return True

def get_guess(guessed_letters):
    '''input for your guesseses'''
    while True:
        guess = input("your guess: ").lower().strip()
        if get_valid_guess(guess, guessed_letters):
            return guess

# 6. update_display() – fills in correct letters
def update_display(word, display_list, guess):
    ''' makes the word into a list of letters log each letters position and identifys the letters then checks if the guess is one of the letters'''
    for index, letter in enumerate(word):
        if letter == guess:
            display_list[index] = guess
    return display_list

# 7. update_wrong_guesses() – tracks incorrect guesses
def update_wrong_guesses(guess, wrong_letters):
    wrong_letters.add(guess)
    '''add wrong guesses to the wrong guesses set'''
    return wrong_letters

# 8. check_win() – no blanks remain
def check_win(display_list):
    '''checks if there are no "_" left in the display'''
    return "_" not in display_list

# 9. check_loss() – 6 incorrect guesses
def check_loss(wrong_letters):
    '''if full hangman showes you lose'''
    max_wrong = len(HANGMAN_PICS) - 1
    return len(wrong_letters) >= max_wrong

# 12. show_results() – prints statistics
def show_results(stats):
    '''prints the game stats'''
    print("\nFinal results for all players:")
    print("------------------------------")
    for name, record in stats.items():
        wins = record['wins']
        losses = record['losses']
        correct = record['correct']
        incorrect = record['incorrect']

        print(
            f"{name}: "
            f"{wins} {pluralise(wins, 'win')}, "
            f"{losses} {pluralise(losses, 'loss', 'losses')}, "
            f"{correct} {pluralise(correct, 'correct guess')}, "
            f"{incorrect} {pluralise(incorrect, 'incorrect guess')}"
        )

# shows the hang man stage 
def show_hangman(wrong_count):
    '''creates the hang man picture'''
    index = min(wrong_count, len(HANGMAN_PICS) - 1)
    print(HANGMAN_PICS[index])

# 10. play_round() – inner loop for one game
def play_round(stats):
    '''core mechanic for running game loop'''
    word = select_word()
    display_list = display(word)
    guessed_letters = set()
    wrong_letters = set()
    correct_guesses = 0
    incorrect_guesses = 0

    while True:
        show_hangman(len(wrong_letters))
        print("Word:", " ".join(display_list))
        print("Incorrect guesses:", " ".join(sorted(wrong_letters)))

        guess = get_guess(guessed_letters)
        guessed_letters.add(guess)

        #point system for the guesses
        if guess in word:
            update_display(word, display_list, guess)
            correct_guesses += 1
        else:
            update_wrong_guesses(guess, wrong_letters)
            incorrect_guesses += 1

        #poit sytem for wins and losses
        if check_win(display_list):
            print("You win! The word was:", word)
            print(f"Correct guesses this round: {correct_guesses}")
            print(f"Incorrect guesses this round: {incorrect_guesses}")

            stats["wins"] += 1
            stats["correct"] += correct_guesses
            stats["incorrect"] += incorrect_guesses
            break

        if check_loss(wrong_letters):
            show_hangman(len(wrong_letters))
            print("You lost! The word was:", word)
            print(f"Correct guesses this round: {correct_guesses}")
            print(f"Incorrect guesses this round: {incorrect_guesses}")

            stats["losses"] += 1
            stats["correct"] += correct_guesses
            stats["incorrect"] += incorrect_guesses
            break

# 11. main() – outer loop for multiple games
def main():
    '''Run the full Hangman game, including multiple players and rounds. Handles player setup, input validation, game loops, and final results.'''
    stats = {}

    while True:
        # Ask for name with validation
        while True:
            name = input("What is your name? ").strip()
            if name:
                name = name.lower()
                break
            print("Invalid name. Please enter at least one character.")

        #creates stat dictonary
        if name not in stats:
            stats[name] = {
                "wins": 0,
                "losses": 0,
                "correct": 0,
                "incorrect": 0
            }

        # Validate play input
        while True:
            play = input(f"Hello {name}, do you want to play Hangman? (y/n): ").lower().strip()
            if play in ("y", "n"):
                break
            print("Invalid input. Please enter 'y' or 'n'.")

        # Play rounds
        while play == "y":
            play_round(stats[name])

            # Validate play again input
            while True:
                play = input("Play again? (y/n): ").lower().strip()
                if play in ("y", "n"):
                    break
                print("Invalid input. Please enter 'y' or 'n'.")

        # Show stats for this player
        wins = stats[name]['wins']
        losses = stats[name]['losses']

        print(f"\n{name}'s stats:")
        print(f"{wins} {pluralise(wins, 'win')}")
        print(f"{losses} {pluralise(losses, 'loss', 'losses')}")

        # Validate another player input
        while True:
            another = input("\nIs there another player? (y/n): ").lower().strip()
            if another in ("y", "n"):
                break
            print("Invalid input. Please enter 'y' or 'n'.")

        if another == "n":
            break

    show_results(stats)

# RUN THE PROGRAM (with try wrapper for marks)
if __name__ == "__main__":
    try:
        main()
    except Exception as e:
        print("\nAn unexpected error occurred:", e)
        #Add consistent docstrings
        #Add comments to complex logic
        #Add correct/incorrect guess stats to lifetime totals
        #Improve naming clarity
        #Add user feedback messages
        #Ensure all input validation loops are consistent
# Out:
# What is your name?  how
# Hello how, do you want to play Hangman? (y/n):  y
#        +---+
#        |   |
#            |
#            |
#            |
#            |
# ...
#
# Word: _ _ _ _ _ _
# Incorrect guesses:
# your guess:  o
#        +---+
#        |   |
#            |
#            |
#            |
#            |
# ...
#
# Word: _ _ _ _ o _
# Incorrect guesses:
# your guess:  a
#        +---+
#        |   |
#            |
#            |
#            |
#            |
# ...
#
# Word: a _ _ _ o _
# Incorrect guesses:
# your guess:  r
#        +---+
#        |   |
#            |
#            |
#            |
#            |
# ...
#
# Word: a _ _ _ o r
# Incorrect guesses:
# your guess:  m
#        +---+
#        |   |
#        O   |
#            |
#            |
#            |
# ...
#
# Word: a _ _ _ o r
# Incorrect guesses: m
# your guess:  m
# Woops, you have already guessed that
# your guess:  l
#        +---+
#        |   |
#        O   |
#        |   |
#            |
#            |
# ...
#
# Word: a _ _ _ o r
# ...

# %%
# 1. Word bank (150 words, no repeats)
word_bank = [
    "planet", "castle", "bridge", "forest", "silver", "hunter", "puzzle", "dragon","window", "garden", "throne", "candle", "butter", "marble", "saddle", "rocket",
    "pirate", "anchor", "helmet", "shield", "wizard", "market", "fabric", "pencil","camera", "ticket", "branch", "stream", "flower", "animal", "desert", "island",
    "throat", "pocket", "button", "string", "circle", "square", "danger", "singer","writer", "reader", "doctor", "farmer", "bottle", "coffee", "cookie", "donkey",
    "rabbit", "kitten", "puppy", "parrot", "eagle", "falcon", "turtle", "shark","salmon", "pepper", "tomato", "cheese", "butter", "pickle", "banana", "orange",
    "grapes", "peach", "apples", "carrot", "potato", "onions", "garlic", "ginger","pepper", "cactus", "planet", "meteor", "galaxy", "cosmic", "rocket", "comet",
    "sunset", "sunrise", "thunder", "lighten", "stormy", "breeze", "winter", "summer","autumn", "spring", "harbor", "vessel", "bridge", "castle", "temple",
    "market","fabric", "cotton", "velvet", "leather", "rubber", "plastic", "copper", "silver","golden", "bronze", "marble", "granite", "crystal", "quartz", "jasper", 
    "onyx","velvet", "thread", "needle", "scarf", "jacket", "trousers", "sweater", "blanket","pillow", "basket", "ladder", "hammer", "chisel", "spirit", "memory", "future",
    "moment", "shadow", "bright", "silent", "noodle", "puzzle", "random", "simple","gentle", "strong", "broken", "smooth", "sticky", "crispy", "salmon", "butter"
]

HANGMAN_PICS = [
    """
       +---+
       |   |
           |
           |
           |
           |
    =========
    """,
    """
       +---+
       |   |
       O   |
           |
           |
           |
    =========
    """,
    """
       +---+
       |   |
       O   |
       |   |
           |
           |
    =========
    """,
    """
       +---+
       |   |
       O   |
      /|   |
           |
           |
    =========
    """,
    """
       +---+
       |   |
       O   |
      /|\  |
           |
           |
    =========
    """,
    """
       +---+
       |   |
       O   |
      /|\  |
      /    |
           |
    =========
    """,
    """
       +---+
       |   |
       O   |
      /|\  |
      / \  |
           |
    =========
    """
]

# 2. IMPORTS
import random

# Pluralisation helper
def pluralise(count, singular, plural=None):
    """Return the correct singular or plural form based on the count."""
    if count == 1:
        return singular
    return plural if plural else singular + "s"

# 3. select_word() – selects a random word
def select_word():
    '''selects a random word from the word bank'''
    return random.choice(word_bank)

# 4. display() – builds the _ _ _ _ blanks
def display(word):
    '''displays the _ _ _ _ to indicate the length of word'''
    return ["_"] * len(word)

# 5. get_guess() – receives and validates player input
def get_valid_guess(guess, guessed_letters):
    '''Validates the player input to ensure it is a single new letter'''
    if len(guess) != 1:
        print("Only 1 letter at a time please")
        return False
    if not guess.isalpha():
        print("Only letters are valid inputs")
        return False
    if guess in guessed_letters:
        print("Woops, you have already guessed that")
        return False
    return True

def get_guess(guessed_letters):
    '''input for your guesseses'''
    while True:
        guess = input("your guess: ").lower().strip()
        if get_valid_guess(guess, guessed_letters):
            return guess

# 6. update_display() – fills in correct letters
def update_display(word, display_list, guess):
    ''' makes the word into a list of letters log each letters position and identifys the letters then checks if the guess is one of the letters'''
    for index, letter in enumerate(word):
        if letter == guess:
            display_list[index] = guess
    return display_list

# 7. update_wrong_guesses() – tracks incorrect guesses
def update_wrong_guesses(guess, wrong_letters):
    wrong_letters.add(guess)
    '''add wrong guesses to the wrong guesses set'''
    return wrong_letters

# 8. check_win() – no blanks remain
def check_win(display_list):
    '''checks if there are no "_" left in the display'''
    return "_" not in display_list

# 9. check_loss() – 6 incorrect guesses
def check_loss(wrong_letters):
    '''if full hangman showes you lose'''
    max_wrong = len(HANGMAN_PICS) - 1
    return len(wrong_letters) >= max_wrong

# 12. show_results() – prints statistics
def show_results(stats):
    '''prints the game stats'''
    print("\nFinal results for all players:")
    print("------------------------------")
    for name, record in stats.items():
        wins = record['wins']
        losses = record['losses']
        correct = record['correct']
        incorrect = record['incorrect']

        print(
            f"{name}: "
            f"{wins} {pluralise(wins, 'win')}, "
            f"{losses} {pluralise(losses, 'loss', 'losses')}, "
            f"{correct} {pluralise(correct, 'correct guess', 'correct guesses')}, "
            f"{incorrect} {pluralise(incorrect, 'incorrect guess', 'incorrect guesses')}"
        )

# shows the hang man stage 
def show_hangman(wrong_count):
    '''creates the hang man picture'''
    index = min(wrong_count, len(HANGMAN_PICS) - 1)
    print(HANGMAN_PICS[index])

# 10. play_round() – inner loop for one game
def play_round(stats):
    '''core mechanic for running game loop'''
    word = select_word()
    display_list = display(word)
    guessed_letters = set()
    wrong_letters = set()
    correct_guesses = 0
    incorrect_guesses = 0

    while True:
        show_hangman(len(wrong_letters))
        print("Word:", " ".join(display_list))
        print("Incorrect guesses:", " ".join(sorted(wrong_letters)))

        guess = get_guess(guessed_letters)
        guessed_letters.add(guess)

        #point system for the guesses
        if guess in word:
            update_display(word, display_list, guess)
            correct_guesses += 1
        else:
            update_wrong_guesses(guess, wrong_letters)
            incorrect_guesses += 1

        #poit sytem for wins and losses
        if check_win(display_list):
            print("You win! The word was:", word)
            print(f"Correct guesses this round: {correct_guesses}")
            print(f"Incorrect guesses this round: {incorrect_guesses}")

            stats["wins"] += 1
            stats["correct"] += correct_guesses
            stats["incorrect"] += incorrect_guesses
            break

        if check_loss(wrong_letters):
            show_hangman(len(wrong_letters))
            print("You lost! The word was:", word)
            print(f"Correct guesses this round: {correct_guesses}")
            print(f"Incorrect guesses this round: {incorrect_guesses}")

            stats["losses"] += 1
            stats["correct"] += correct_guesses
            stats["incorrect"] += incorrect_guesses
            break

# 11. main() – outer loop for multiple games
def main():
    '''Run the full Hangman game, including multiple players and rounds. Handles player setup, input validation, game loops, and final results.'''
    stats = {}

    while True:
        # Ask for name with validation
        while True:
            name = input("What is your name? ").strip()
            if name:
                name = name.lower()
                break
            print("Invalid name. Please enter at least one character.")

        #creates stat dictonary
        if name not in stats:
            stats[name] = {
                "wins": 0,
                "losses": 0,
                "correct": 0,
                "incorrect": 0
            }

        # Validate play input
        while True:
            play = input(f"Hello {name}, do you want to play Hangman? (y/n): ").lower().strip()
            if play in ("y", "n"):
                break
            print("Invalid input. Please enter 'y' or 'n'.")

        # Play rounds
        while play == "y":
            play_round(stats[name])

            # Validate play again input
            while True:
                play = input("Play again? (y/n): ").lower().strip()
                if play in ("y", "n"):
                    break
                print("Invalid input. Please enter 'y' or 'n'.")

        # Show stats for this player
        wins = stats[name]['wins']
        losses = stats[name]['losses']

        print(f"\n{name}'s stats:")
        print(f"{wins} {pluralise(wins, 'win')}")
        print(f"{losses} {pluralise(losses, 'loss', 'losses')}")

        # Validate another player input
        while True:
            another = input("\nIs there another player? (y/n): ").lower().strip()
            if another in ("y", "n"):
                break
            print("Invalid input. Please enter 'y' or 'n'.")

        if another == "n":
            break

    show_results(stats)

# RUN THE PROGRAM (with try wrapper for marks)
if __name__ == "__main__":
    try:
        main()
    except Exception as e:
        print("\nAn unexpected error occurred:", e)
# Out:
# What is your name?  h7

# %% [markdown]
# ### Python Game Project
#
# | Subject                                   | 1–2 Marks                                                                                                                                                                                                 | 3–4 Marks                                                                                                                                                                                                 | 5 Marks                                                                                                                                                                                                                  |
# |--------------------------------------------|----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | **Game Logic & Design (Flowchart)**        | Flowchart is unclear, incomplete, or does not represent the game logic accurately. Major steps or decisions are missing, or the flow is confusing and hard to follow.                                     | Flowchart covers most main steps and decisions, but may have some missing elements or minor clarity issues. Logic is mostly correct but could be clearer.                                                | Flowchart is clear, complete, and accurately represents the game’s logic and structure. All key decisions and steps are included, and the flow is easy to follow.                                                        |
# | **Technical Implementation & Effectiveness** | Functions are missing, poorly structured, or not used appropriately. Code does not follow best practices (e.g., poor naming, repetition, lack of modularity). Game does not work as intended, has major errors, or is not engaging. Poor error handling. | Functions are present and mostly appropriate, but may lack clarity or consistency. Some best practices are followed, but there are areas for improvement. Game mostly works, but may have some issues or lack engagement. Some error handling present. | Functions are well-designed, clearly named, and used effectively to structure the code. Code follows best practices throughout, is clean, well-organised, and easy to read. Game works well, is engaging, and handles errors effectively. |
# | **Documentation & Presentation**           | Code is difficult to read, poorly commented, and lacks docstrings. Variable and function names are unclear. No or minimal documentation. README file is missing or unhelpful. Presentation is missing or unclear.             | Some comments and docstrings are present, but may lack detail or consistency. Code is somewhat readable, but could be improved. README file is present but basic or incomplete. Presentation covers basics but lacks detail or clarity.                   | Code is well-documented, with comprehensive comments and clear docstrings. Naming is clear and consistent. README file is clear, detailed, and helpful. Presentation is clear, confident, and explains the game’s features and logic well.              |
